# %%
# %pip install pydataxm
# Out:
# Requirement already satisfied: pydataxm in /usr/local/lib/python3.11/dist-packages (0.3.16)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from pydataxm) (2.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pydataxm) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pydataxm) (2.32.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from pydataxm) (3.12.14)
# Requirement already satisfied: asyncio in /usr/local/lib/python3.11/dist-packages (from pydataxm) (3.4.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from pydataxm) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->pydataxm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->pydataxm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->pydataxm) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->pydataxm) (1.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pydataxm) (2025.7.14)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->pydataxm) (4.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->pydataxm) (1.17.0)

# %%
from pydataxm.pydatasimem import ReadSIMEM, CatalogSIMEM
import pandas as pd

# Crear una instancia de catalogo con el tipo
catalogo_conjuntos = CatalogSIMEM('Datasets')

#  Dataframe con información de los conjuntos de datos
data = catalogo_conjuntos.get_data()
data.to_excel("Catálogo.xlsx")

# %%
from pydataxm.pydatasimem import ReadSIMEM, CatalogSIMEM

# Crear una instancia de ReadSIMEM
dataset_id = 'E17D25'
fecha_inicio = '2013-01-01'
fecha_fin = '2025-07-17'

generacion = ReadSIMEM(dataset_id, fecha_inicio, fecha_fin).main(filter=False)
generacion.to_csv('dataset.csv',index=False)
generacion.head()
# Out:
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Generación Real y Programada en las Plantas de Generación"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0038826465606689453
# Extraccion de registros: 927.1386518478394
# End of data extracting process
# ****************************************************************************************************
#         Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 0  2013-01-31         RFR1     Hidraulica        Hidraulica
# 1  2013-01-31         IQU1     Hidraulica        Hidraulica
# 2  2013-01-31         NQU1     Hidraulica        Hidraulica
# 3  2013-01-31         LPLO     Hidraulica        Hidraulica
# 4  2013-01-31         CPT1     Hidraulica        Hidraulica
#
#           TipoDespachoRecurso  GeneracionRealEstimada  \
# 0  No Despachado Centralmente                13730.31
# 1  No Despachado Centralmente                55080.00
# 2  No Despachado Centralmente               320892.00
# 3  No Despachado Centralmente                18033.00
# 4  No Despachado Centralmente                10440.00
#
#    GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                      13730.31                        13730.31
# 1                      55080.00                        55080.00
# 2                     320892.00                       320892.00
# 3                      18033.00                        18033.00
# 4                      10440.00                        10440.00
